# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
E = 4
tau = 100e-6

# %%
def impulse(t, E, tau):
    if abs(t)>tau/2:
        return 0.0
    return E

def spectrum(f, E, tau):
    if np.isclose(f, 0):
        return E*tau
    return E*tau*np.sinc(tau*f)

t_band = np.linspace(-2*tau, 2*tau, num=2**14)
f_band = np.linspace(-5/tau, 5/tau, num=2**14)
x = np.array([impulse(t, E, tau) for t in t_band])
Xf = np.array([spectrum(f, E, tau) for f in f_band])

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(t_band*1e6, x)
plt.title("Импульс $x_1(t)$")
plt.xlabel("$t$, мкc")
plt.ylabel("$x_1(t)$, В")
plt.tight_layout()
plt.grid()

plt.subplot(2, 1, 2)
plt.title("АЧХ импульса $x_1(t)$")
plt.plot(f_band*1e-3, abs(Xf)*1e6)
plt.ylabel("$|X_1(f)|$, мкВ/Гц")
plt.xlabel("$f$, кГц")
plt.tight_layout()
plt.grid()

plt.savefig("A.png")
# Out:
# C:\Users\danit\AppData\Local\Temp\ipykernel_9108\4039818451.py:30: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
def impulse(t, E, tau):
    if (t > tau) or (t < 0):
        return 0.0
    return E

def spectrum(f, E, tau):
    if np.isclose(f, 0):
        return E*tau
    return E*tau*np.sinc(f*tau) * np.exp(-1j*np.pi*f*tau)

t_band = np.linspace(-2*tau, 2*tau, num=2**14)
f_band = np.linspace(-5/tau, 5/tau, num=2**14)
x = np.array([impulse(t, E, tau) for t in t_band])
Xf = np.array([spectrum(f, E, tau) for f in f_band])

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(t_band*1e6, x)
plt.title("Импульс $x_2(t)$")
plt.xlabel("$t$, мкc")
plt.ylabel("$x_2(t)$, В")
plt.tight_layout()
plt.grid()

plt.subplot(2, 1, 2)
plt.title("АЧХ импульса $x_2(t)$")
plt.plot(f_band*1e-3, abs(Xf)*1e6)
plt.ylabel("$|X_2(f)|$, мкВ/Гц")
plt.xlabel("$f$, кГц")
plt.tight_layout()
plt.grid()

plt.savefig("B.png")
# Out:
# C:\Users\danit\AppData\Local\Temp\ipykernel_9108\4260774827.py:30: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
def impulse(t, E, tau):
    if abs(t) >= tau/2:
        return 0.0
    return E * np.cos(np.pi*t/tau)

def spectrum(f, E, tau):
    return E*tau/2 *(np.sinc(tau*f - 1/2) + np.sinc(tau*f + 1/2))

t_band = np.linspace(-2*tau, 2*tau, num=2**14)
f_band = np.linspace(-5/tau, 5/tau, num=2**14)
x = np.array([impulse(t, E, tau) for t in t_band])
Xf = np.array([spectrum(f, E, tau) for f in f_band])

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(t_band*1e6, x)
plt.title("Импульс $x_3(t)$")
plt.xlabel("$t$, мкc")
plt.ylabel("$x_3(t)$, В")
plt.tight_layout()
plt.grid()

plt.subplot(2, 1, 2)
plt.title("АЧХ импульса $x_3(t)$")
plt.plot(f_band*1e-3, abs(Xf)*1e6)
plt.ylabel("$|X_3(f)|$, мкВ/Гц")
plt.xlabel("$f$, кГц")
plt.tight_layout()
plt.grid()

plt.savefig("С.png")
# Out:
# C:\Users\danit\AppData\Local\Temp\ipykernel_9108\852974573.py:28: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
def impulse(t, E, tau):
    if (t > tau) or (t < 0):
        return 0.0
    return E * np.cos(np.pi*t/tau)

def spectrum(f, E, tau):
    return E*tau/2 *(np.sinc(tau*f - 1/2) + np.sinc(tau*f + 1/2)) * np.exp(-1j*np.pi*f*tau)

t_band = np.linspace(-2*tau, 2*tau, num=2**14)
f_band = np.linspace(-5/tau, 5/tau, num=2**14)
x = np.array([impulse(t, E, tau) for t in t_band])
Xf = np.array([spectrum(f, E, tau) for f in f_band])

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(t_band*1e6, x)
plt.title("Импульс $x_4(t)$")
plt.xlabel("$t$, мкc")
plt.ylabel("$x_4(t)$, В")
plt.tight_layout()
plt.grid()

plt.subplot(2, 1, 2)
plt.title("АЧХ импульса $x_4(t)$")
plt.plot(f_band*1e-3, abs(Xf)*1e6)
plt.ylabel("$|X_4(f)|$, мкВ/Гц")
plt.xlabel("$f$, кГц")
plt.tight_layout()
plt.grid()

plt.savefig("D.png")
# Out:
# C:\Users\danit\AppData\Local\Temp\ipykernel_9108\356543661.py:28: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
def impulse(t, E, tau):
    if abs(t) >= tau/2:
        return 0.0
    return 1/2*(1 + np.cos(2*np.pi*t/tau))

def spectrum(f, E, tau):
    return tau/2*np.sinc(f*tau) + tau/4*(np.sinc(f*tau - 1) + np.sinc(f*tau + 1))

t_band = np.linspace(-2*tau, 2*tau, num=2**14)
f_band = np.linspace(-5/tau, 5/tau, num=2**14)
x = np.array([impulse(t, E, tau) for t in t_band])
Xf = np.array([spectrum(f, E, tau) for f in f_band])

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(t_band*1e6, x)
plt.title("Импульс $x_5(t)$")
plt.xlabel("$t$, мкc")
plt.ylabel("$x_5(t)$, В")
plt.tight_layout()
plt.grid()

plt.subplot(2, 1, 2)
plt.title("АЧХ импульса $x_5(t)$")
plt.plot(f_band*1e-3, abs(Xf)*1e6)
plt.ylabel("$|X_5(f)|$, мкВ/Гц")
plt.xlabel("$f$, кГц")
plt.tight_layout()
plt.grid()

plt.savefig("E.png")
# Out:
# C:\Users\danit\AppData\Local\Temp\ipykernel_9108\3338691179.py:28: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
def impulse(t, E, tau):
    if (t > tau) or (t < 0):
        return 0.0
    return 1/2*(1 + np.cos(2*np.pi*t/tau))

def spectrum(f, E, tau):
    return (tau/2*np.sinc(f*tau) + tau/4*(np.sinc(f*tau - 1) + np.sinc(f*tau + 1))) * np.exp(-1j*np.pi*f*tau)

t_band = np.linspace(-2*tau, 2*tau, num=2**14)
f_band = np.linspace(-5/tau, 5/tau, num=2**14)
x = np.array([impulse(t, E, tau) for t in t_band])
Xf = np.array([spectrum(f, E, tau) for f in f_band])

plt.figure()
plt.subplot(2, 1, 1)
plt.plot(t_band*1e6, x)
plt.title("Импульс $x_6(t)$")
plt.xlabel("$t$, мкc")
plt.ylabel("$x_6(t)$, В")
plt.tight_layout()
plt.grid()

plt.subplot(2, 1, 2)
plt.title("АЧХ импульса $x_6(t)$")
plt.plot(f_band*1e-3, abs(Xf)*1e6)
plt.ylabel("$|X_6(f)|$, мкВ/Гц")
plt.xlabel("$f$, кГц")
plt.tight_layout()
plt.grid()

plt.savefig("F.png")
# Out:
# C:\Users\danit\AppData\Local\Temp\ipykernel_9108\3911016919.py:28: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
